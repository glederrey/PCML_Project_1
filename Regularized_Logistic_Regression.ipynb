# %% [markdown]
# # ML with Regularized Logistic Regression
#
# In this notebook, we will use the functions in the file regularized_logistic_regression.py.

# %%
# Useful starting lines
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
from IPython import display
# Import everything in the functions folder
from functions.costs import *
from functions.proj1_helpers import *
from functions.split import *
from functions.regularized_logistic_regression import *
from functions.helpers import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# First, we load the data

# %%
DATA_TRAIN_PATH = 'data/train_cleaned.csv' 
y, tX, ids = load_csv_data(DATA_TRAIN_PATH)
tX, mean_tX, std_tX = standardize(tX)

# %% [markdown]
# We split the data, just to see if we can predict something

# %%
ratio = 0.8
x_train, y_train, x_test, y_test = split_data(tX, y, ratio)

# %% [markdown]
# We plot the graph Loss vs Epochs while doing the Regularized Logistic Regression

# %%
# Define the parameters of the algorithm.
max_iters = 600
gamma = 1e-7
lambda_ = 2

# Initialization
losses, ws = regularized_logistic_regression(y_train, x_train, gamma, lambda_, max_iters)
# Out:
# ---------------------------------------
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-11-e9d86cbc793d> in <module>()
#       5
#       6 # Initialization
# ----> 7 losses, ws = regularized_logistic_regression(y_train, x_train, gamma, lambda_, max_iters)
#
# /home/gael/Documents/EPFL/Master_CSE/MA5/PCML/PCML_Project_1/functions/regularized_logistic_regression.py in regularized_logistic_regression(y, tx, gamma, lambda_, max_iters)
#      69         plt.semilogy(iterations, losses, '-*b')
#      70         plt.title("Loss in function of epochs.\nLast loss = %10.3e"%loss)
# ---> 71         display.display(plt.gcf())
#      72         display.clear_output(wait=True)
#      73
#
# /home/gael/anaconda3/lib/python3.5/site-packages/IPython/core/display.py in display(*objs, **kwargs)
#     156             publish_display_data(data=obj, metadata=metadata)
#     157         else:
# --> 158             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     159             if not format_dict:
#     160                 # nothing to display (e.g. _ipython_display_ took over)
#
# /home/gael/anaconda3/lib/python3.5/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     175             md = None
#     176             try:
# --> 177                 data = formatter(obj)
#     178             except:
#     179                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# /home/gael/anaconda3/lib/python3.5/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     220     """show traceback on failed format call"""
#     221     try:
# --> 222         r = method(self, *args, **kwargs)
#     223     except NotImplementedError:
#     224         # don't warn on NotImplementedErrors
#
# /home/gael/anaconda3/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     337                 pass
#     338             else:
# --> 339                 return printer(obj)
#     340             # Finally look for special method names
#     341             method = _safe_get_formatter_method(obj, self.print_method)
#
# /home/gael/anaconda3/lib/python3.5/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     226
#     227     if 'png' in formats:
# --> 228         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     229     if 'retina' in formats or 'png2x' in formats:
#     230         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /home/gael/anaconda3/lib/python3.5/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     117
#     118     bytes_io = BytesIO()
# --> 119     fig.canvas.print_figure(bytes_io, **kw)
#     120     data = bytes_io.getvalue()
#     121     if fmt == 'svg':
#
# /home/gael/anaconda3/lib/python3.5/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2178                     orientation=orientation,
#    2179                     dryrun=True,
# -> 2180                     **kwargs)
#    2181                 renderer = self.figure._cachedRenderer
#    2182                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# /home/gael/anaconda3/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     525
#     526     def print_png(self, filename_or_obj, *args, **kwargs):
# --> 527         FigureCanvasAgg.draw(self)
#     528         renderer = self.get_renderer()
#     529         original_dpi = renderer.dpi
#
# /home/gael/anaconda3/lib/python3.5/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     472
#     473         try:
# --> 474             self.figure.draw(self.renderer)
#     475         finally:
#     476             RendererAgg.lock.release()
#
# /home/gael/anaconda3/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /home/gael/anaconda3/lib/python3.5/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1157         dsu.sort(key=itemgetter(0))
#    1158         for zorder, a, func, args in dsu:
# -> 1159             func(*args)
#    1160
#    1161         renderer.close_group('figure')
#
# /home/gael/anaconda3/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /home/gael/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2322
#    2323         for zorder, a in dsu:
# -> 2324             a.draw(renderer)
#    2325
#    2326         renderer.close_group('axes')
#
# /home/gael/anaconda3/lib/python3.5/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      59     def draw_wrapper(artist, renderer, *args, **kwargs):
#      60         before(artist, renderer)
# ---> 61         draw(artist, renderer, *args, **kwargs)
#      62         after(artist, renderer)
#      63
#
# /home/gael/anaconda3/lib/python3.5/site-packages/matplotlib/lines.py in draw(self, renderer)
#     763             self._set_gc_clip(gc)
#     764             rgbaFace = self._get_rgba_face()
# --> 765             rgbaFaceAlt = self._get_rgba_face(alt=True)
#     766             edgecolor = self.get_markeredgecolor()
#     767             if is_string_like(edgecolor) and edgecolor.lower() == 'none':
#
# /home/gael/anaconda3/lib/python3.5/site-packages/matplotlib/lines.py in _get_rgba_face(self, alt)
#    1241
#    1242     def _get_rgba_face(self, alt=False):
# -> 1243         facecolor = self._get_markerfacecolor(alt=alt)
#    1244         if is_string_like(facecolor) and facecolor.lower() == 'none':
#    1245             rgbaFace = None
#
# /home/gael/anaconda3/lib/python3.5/site-packages/matplotlib/lines.py in _get_markerfacecolor(self, alt)
#     866             fc = self._markerfacecolor
#     867
# --> 868         if (is_string_like(fc) and fc.lower() == 'auto'):
#     869             if self.get_fillstyle() == 'none':
#     870                 return 'none'
#
# /home/gael/anaconda3/lib/python3.5/site-packages/matplotlib/cbook.py in is_string_like(obj)
#     696 def is_string_like(obj):
#     697     'Return True if *obj* looks like a string'
# --> 698     if isinstance(obj, six.string_types):
#     699         return True
#     700     # numpy strings are subclass of str, ma strings are not
#
# KeyboardInterrupt:
